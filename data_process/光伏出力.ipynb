# %%
import pandas as pd
import numpy as np
from pylab import mpl,plt

# %%
df=pd.read_excel("PV_power.xlsx")
df
# Out:
#      time  P/Pmax
# 0    0.25   0.000
# 1    0.50   0.000
# 2    0.75   0.000
# 3    1.00   0.000
# 4    1.25   0.000
# 5    1.50   0.000
# 6    1.75   0.000
# 7    2.00   0.000
# 8    2.25   0.000
# 9    2.50   0.000
# 10   2.75   0.000
# 11   3.00   0.000
# 12   3.25   0.000
# 13   3.50   0.000
# 14   3.75   0.000
# 15   4.00   0.000
# 16   4.25   0.000
# 17   4.50   0.000
# 18   4.75   0.000
# 19   5.00   0.000
# 20   5.25   0.000
# 21   5.50   0.000
# 22   5.75   0.000
# 23   6.00   0.000
# 24   6.25   0.000
# 25   6.50   0.005
# 26   6.75   0.010
# 27   7.00   0.033
# 28   7.25   0.046
# 29   7.50   0.075
# ..    ...     ...
# 66  16.75   0.265
# 67  17.00   0.210
# 68  17.25   0.182
# 69  17.50   0.150
# 70  17.75   0.079
# 71  18.00   0.058
# 72  18.25   0.047
# 73  18.50   0.023
# 74  18.75   0.013
# 75  19.00   0.003
# 76  19.25   0.001
# 77  19.50   0.000
# 78  19.75   0.000
# 79  20.00   0.000
# 80  20.25   0.000
# 81  20.50   0.000
# 82  20.75   0.000
# 83  21.00   0.000
# ...

# %%
df["P/Pmax"].plot()
plt.show()
